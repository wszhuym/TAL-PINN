# %%
import os
import numpy as np

import jax
import jax.numpy as jnp
from jax import jacfwd, vmap
from functools import partial
from typing import NamedTuple, Sequence, Callable

import flax.linen as nn
import optax
from soap_jax import soap

import time
import scipy.io
import matplotlib.pyplot as plt

from flax import serialization

from Utilities_pinn_burgers1d_moving import *

# %%
# 1. Data
data = scipy.io.loadmat("burgers_godunov2.mat")

#data = scipy.io.loadmat("burgers_riemann.mat")

U0 = jnp.asarray(data["U"][::2,::2])
X0 = jnp.asarray(data["X"][::2,::2])
T0 = jnp.asarray(data["T"][::2,::2])

Nt_test, Nx_test = U0.shape
t_test = T0.reshape(-1)
x_test = X0.reshape(-1)
test_inputs = jnp.stack([t_test, x_test], axis=-1)
test_labels = U0.reshape(-1, 1)

x_unique = np.unique(np.asarray(X0))
interface_idx = int(np.argmin(np.abs(x_unique - 0.5)))
interface_x = float(x_unique[interface_idx])

print(f"Test grid: Nt={Nt_test}, Nx={Nx_test}")
print(f"Interface x={interface_x:.8f}, index={interface_idx}")

plt.figure(figsize=(5.5, 4))
plt.contourf(X0, T0, U0, levels=50, cmap='jet')
plt.colorbar(label='U')
plt.xlabel('x')
plt.ylabel('t')
plt.title('U')
plt.tight_layout()
plt.show()
# Out:
# Test grid: Nt=513, Nx=513
# Interface x=0.50000000, index=256

# %%
# 2. Keep the PDE initialization/training keys aligned with TAL-PINN.
seed = 49
save_path = "pinn_burgers_movinge09.msgpack"

key = jax.random.PRNGKey(seed)
key_pde_init, _, key_train = jax.random.split(key, 3)

# 3. Vanilla PINN on physical coordinates [t, x]
pde_net = FNN_fourier(layer_sizes=[40, 40, 1], fourier_dim=20)
pde_params = pde_net.init(key_pde_init, jnp.ones((2,), dtype=T0.dtype))

pde_optimizer = soap(learning_rate=3.0e-3, b1=0.95, b2=0.95, weight_decay=0.01, precondition_frequency=10, precondition_1d=False)

pde_loss_grad_fn = create_pde_loss_grad_fn(pde_net)
pde_minibatch_fn = create_pde_minibatch_fn(IC_Burgers, BC_Burgers)
eval_fn = create_eval_fn(pde_net, nx_test=Nx_test, interface_idx=interface_idx, interface_mode="drop")

# %%
# 4. One direct training stage at the target viscosity.
pde_params, key_train, history = train_pde_stage(stage_name="Vanilla PINN", pde_params=pde_params, pde_optimizer=pde_optimizer, pde_loss_grad_fn=pde_loss_grad_fn, pde_minibatch_fn=pde_minibatch_fn,
    eval_fn=eval_fn, test_inputs=test_inputs, test_labels=test_labels,
    key=key_train, nu=1.0e-4, max_iters=8000, pts_pde=10000, pts_ics=1000, pts_bcs=1000, max_runtime=10000.0, eval_every=100)

save_training_results(pde_params=pde_params, pde_history=history, checkpoint_path=save_path)

plot_training_history(history, metric="rl2", title="Vanilla PINN training history")
plot_evaluation(params=pde_params, model=pde_net, t_test=t_test, x_test=x_test, labels_test=test_labels, interface_x=interface_x, 
    metric_interface_mode="drop", plot_interface_mode="none")
# Out:
# [Vanilla PINN] JIT warm-up finished.
# [Vanilla PINN] iter = 00000, time = 0.00s | mse = 1.04e+00, rl2 = 1.70e+00
# [Vanilla PINN] iter = 00100, time = 0.57s, loss = 7.71e-01 | mse = 1.31e-01, rl2 = 6.05e-01
# [Vanilla PINN] iter = 00200, time = 0.87s, loss = 5.37e-01 | mse = 5.60e-02, rl2 = 3.96e-01
# [Vanilla PINN] iter = 00300, time = 1.17s, loss = 5.18e-01 | mse = 4.87e-02, rl2 = 3.69e-01
# [Vanilla PINN] iter = 00400, time = 1.47s, loss = 5.29e-01 | mse = 4.71e-02, rl2 = 3.63e-01
# [Vanilla PINN] iter = 00500, time = 1.77s, loss = 5.22e-01 | mse = 4.64e-02, rl2 = 3.61e-01
# [Vanilla PINN] iter = 00600, time = 2.07s, loss = 4.91e-01 | mse = 4.41e-02, rl2 = 3.51e-01
# [Vanilla PINN] iter = 00700, time = 2.37s, loss = 5.11e-01 | mse = 4.35e-02, rl2 = 3.49e-01
# [Vanilla PINN] iter = 00800, time = 2.67s, loss = 5.02e-01 | mse = 4.34e-02, rl2 = 3.49e-01
# [Vanilla PINN] iter = 00900, time = 2.97s, loss = 5.04e-01 | mse = 4.33e-02, rl2 = 3.48e-01
# [Vanilla PINN] iter = 01000, time = 3.27s, loss = 5.13e-01 | mse = 4.24e-02, rl2 = 3.45e-01
# [Vanilla PINN] iter = 01100, time = 3.57s, loss = 5.07e-01 | mse = 4.21e-02, rl2 = 3.44e-01
# [Vanilla PINN] iter = 01200, time = 3.87s, loss = 5.02e-01 | mse = 4.13e-02, rl2 = 3.40e-01
# [Vanilla PINN] iter = 01300, time = 4.17s, loss = 5.04e-01 | mse = 4.17e-02, rl2 = 3.42e-01
# [Vanilla PINN] iter = 01400, time = 4.47s, loss = 4.86e-01 | mse = 4.16e-02, rl2 = 3.41e-01
# [Vanilla PINN] iter = 01500, time = 4.77s, loss = 4.89e-01 | mse = 4.14e-02, rl2 = 3.41e-01
# [Vanilla PINN] iter = 01600, time = 5.07s, loss = 4.84e-01 | mse = 4.05e-02, rl2 = 3.37e-01
# [Vanilla PINN] iter = 01700, time = 5.38s, loss = 4.86e-01 | mse = 4.04e-02, rl2 = 3.37e-01
# [Vanilla PINN] iter = 01800, time = 5.68s, loss = 4.84e-01 | mse = 4.16e-02, rl2 = 3.41e-01
# [Vanilla PINN] iter = 01900, time = 5.98s, loss = 4.93e-01 | mse = 4.12e-02, rl2 = 3.40e-01
# [Vanilla PINN] iter = 02000, time = 6.28s, loss = 4.99e-01 | mse = 4.03e-02, rl2 = 3.36e-01
# [Vanilla PINN] iter = 02100, time = 6.58s, loss = 4.82e-01 | mse = 4.04e-02, rl2 = 3.37e-01
# [Vanilla PINN] iter = 02200, time = 6.88s, loss = 5.02e-01 | mse = 4.04e-02, rl2 = 3.36e-01
# [Vanilla PINN] iter = 02300, time = 7.18s, loss = 4.96e-01 | mse = 4.01e-02, rl2 = 3.35e-01
# [Vanilla PINN] iter = 02400, time = 7.48s, loss = 4.89e-01 | mse = 4.08e-02, rl2 = 3.38e-01
# [Vanilla PINN] iter = 02500, time = 7.78s, loss = 4.98e-01 | mse = 4.29e-02, rl2 = 3.47e-01
# [Vanilla PINN] iter = 02600, time = 8.08s, loss = 5.02e-01 | mse = 3.98e-02, rl2 = 3.34e-01
# [Vanilla PINN] iter = 02700, time = 8.38s, loss = 4.83e-01 | mse = 4.06e-02, rl2 = 3.37e-01
# [Vanilla PINN] iter = 02800, time = 8.68s, loss = 4.97e-01 | mse = 4.09e-02, rl2 = 3.38e-01
# [Vanilla PINN] iter = 02900, time = 8.98s, loss = 4.87e-01 | mse = 4.05e-02, rl2 = 3.37e-01
# [Vanilla PINN] iter = 03000, time = 9.28s, loss = 4.88e-01 | mse = 4.04e-02, rl2 = 3.36e-01
# [Vanilla PINN] iter = 03100, time = 9.58s, loss = 4.81e-01 | mse = 3.84e-02, rl2 = 3.28e-01
# [Vanilla PINN] iter = 03200, time = 9.88s, loss = 4.84e-01 | mse = 3.99e-02, rl2 = 3.34e-01
# [Vanilla PINN] iter = 03300, time = 10.18s, loss = 4.95e-01 | mse = 4.07e-02, rl2 = 3.38e-01
# [Vanilla PINN] iter = 03400, time = 10.48s, loss = 4.83e-01 | mse = 4.16e-02, rl2 = 3.41e-01
# [Vanilla PINN] iter = 03500, time = 10.78s, loss = 4.92e-01 | mse = 3.95e-02, rl2 = 3.33e-01
# [Vanilla PINN] iter = 03600, time = 11.08s, loss = 4.76e-01 | mse = 3.93e-02, rl2 = 3.32e-01
# [Vanilla PINN] iter = 03700, time = 11.37s, loss = 4.89e-01 | mse = 3.89e-02, rl2 = 3.30e-01
# [Vanilla PINN] iter = 03800, time = 11.67s, loss = 4.85e-01 | mse = 4.13e-02, rl2 = 3.40e-01
# [Vanilla PINN] iter = 03900, time = 11.97s, loss = 4.89e-01 | mse = 3.92e-02, rl2 = 3.31e-01
# [Vanilla PINN] iter = 04000, time = 12.26s, loss = 4.85e-01 | mse = 4.61e-02, rl2 = 3.59e-01
# [Vanilla PINN] iter = 04100, time = 12.56s, loss = 4.81e-01 | mse = 3.92e-02, rl2 = 3.31e-01
# [Vanilla PINN] iter = 04200, time = 12.86s, loss = 4.87e-01 | mse = 3.88e-02, rl2 = 3.30e-01
# [Vanilla PINN] iter = 04300, time = 13.15s, loss = 4.73e-01 | mse = 4.02e-02, rl2 = 3.36e-01
# [Vanilla PINN] iter = 04400, time = 13.45s, loss = 4.79e-01 | mse = 4.04e-02, rl2 = 3.37e-01
# [Vanilla PINN] iter = 04500, time = 13.75s, loss = 4.73e-01 | mse = 3.89e-02, rl2 = 3.30e-01
# [Vanilla PINN] iter = 04600, time = 14.04s, loss = 4.75e-01 | mse = 4.29e-02, rl2 = 3.47e-01
# [Vanilla PINN] iter = 04700, time = 14.34s, loss = 4.91e-01 | mse = 5.27e-02, rl2 = 3.84e-01
# [Vanilla PINN] iter = 04800, time = 14.64s, loss = 4.65e-01 | mse = 3.95e-02, rl2 = 3.33e-01
# [Vanilla PINN] iter = 04900, time = 14.94s, loss = 4.67e-01 | mse = 3.70e-02, rl2 = 3.22e-01
# [Vanilla PINN] iter = 05000, time = 15.23s, loss = 4.77e-01 | mse = 4.08e-02, rl2 = 3.38e-01
# [Vanilla PINN] iter = 05100, time = 15.53s, loss = 4.73e-01 | mse = 3.84e-02, rl2 = 3.28e-01
# [Vanilla PINN] iter = 05200, time = 15.83s, loss = 4.67e-01 | mse = 3.68e-02, rl2 = 3.21e-01
# [Vanilla PINN] iter = 05300, time = 16.12s, loss = 4.68e-01 | mse = 4.37e-02, rl2 = 3.50e-01
# [Vanilla PINN] iter = 05400, time = 16.42s, loss = 4.56e-01 | mse = 4.65e-02, rl2 = 3.61e-01
# [Vanilla PINN] iter = 05500, time = 16.72s, loss = 4.66e-01 | mse = 4.72e-02, rl2 = 3.64e-01
# [Vanilla PINN] iter = 05600, time = 17.01s, loss = 4.48e-01 | mse = 3.56e-02, rl2 = 3.16e-01
# [Vanilla PINN] iter = 05700, time = 17.31s, loss = 4.66e-01 | mse = 5.58e-02, rl2 = 3.95e-01
# [Vanilla PINN] iter = 05800, time = 17.61s, loss = 4.37e-01 | mse = 3.76e-02, rl2 = 3.25e-01
# [Vanilla PINN] iter = 05900, time = 17.90s, loss = 4.42e-01 | mse = 4.57e-02, rl2 = 3.58e-01
# [Vanilla PINN] iter = 06000, time = 18.20s, loss = 4.32e-01 | mse = 3.59e-02, rl2 = 3.17e-01
# [Vanilla PINN] iter = 06100, time = 18.50s, loss = 4.55e-01 | mse = 4.43e-02, rl2 = 3.52e-01
# [Vanilla PINN] iter = 06200, time = 18.79s, loss = 4.61e-01 | mse = 6.38e-02, rl2 = 4.23e-01
# [Vanilla PINN] iter = 06300, time = 19.09s, loss = 4.73e-01 | mse = 7.71e-02, rl2 = 4.65e-01
# [Vanilla PINN] iter = 06400, time = 19.39s, loss = 4.36e-01 | mse = 3.50e-02, rl2 = 3.13e-01
# [Vanilla PINN] iter = 06500, time = 19.69s, loss = 4.14e-01 | mse = 3.69e-02, rl2 = 3.21e-01
# [Vanilla PINN] iter = 06600, time = 19.98s, loss = 4.21e-01 | mse = 4.02e-02, rl2 = 3.35e-01
# [Vanilla PINN] iter = 06700, time = 20.28s, loss = 4.13e-01 | mse = 3.81e-02, rl2 = 3.27e-01
# [Vanilla PINN] iter = 06800, time = 20.58s, loss = 4.26e-01 | mse = 5.17e-02, rl2 = 3.81e-01
# [Vanilla PINN] iter = 06900, time = 20.87s, loss = 4.93e-01 | mse = 8.72e-02, rl2 = 4.94e-01
# [Vanilla PINN] iter = 07000, time = 21.17s, loss = 4.52e-01 | mse = 7.97e-02, rl2 = 4.72e-01
# [Vanilla PINN] iter = 07100, time = 21.47s, loss = 4.20e-01 | mse = 6.07e-02, rl2 = 4.12e-01
# [Vanilla PINN] iter = 07200, time = 21.77s, loss = 3.80e-01 | mse = 5.32e-02, rl2 = 3.86e-01
# [Vanilla PINN] iter = 07300, time = 22.06s, loss = 4.19e-01 | mse = 7.12e-02, rl2 = 4.47e-01
# [Vanilla PINN] iter = 07400, time = 22.36s, loss = 3.99e-01 | mse = 4.82e-02, rl2 = 3.67e-01
# [Vanilla PINN] iter = 07500, time = 22.66s, loss = 3.81e-01 | mse = 4.27e-02, rl2 = 3.46e-01
# [Vanilla PINN] iter = 07600, time = 22.95s, loss = 3.73e-01 | mse = 3.64e-02, rl2 = 3.19e-01
# [Vanilla PINN] iter = 07700, time = 23.25s, loss = 3.49e-01 | mse = 3.58e-02, rl2 = 3.17e-01
# [Vanilla PINN] iter = 07800, time = 23.56s, loss = 3.60e-01 | mse = 2.96e-02, rl2 = 2.88e-01
# [Vanilla PINN] iter = 07900, time = 23.85s, loss = 3.57e-01 | mse = 3.15e-02, rl2 = 2.97e-01
# [Vanilla PINN] iter = 08000, time = 24.16s, loss = 3.39e-01 | mse = 3.25e-02, rl2 = 3.02e-01
# Training checkpoint saved to: /home/DG21210022/Amon/tal/burgers/pinn_burgers_movinge09.msgpack
# Training history saved to: /home/DG21210022/Amon/tal/burgers/pinn_burgers_movinge09_history.npz
# Plotting... Test grid shape: nt=513, nx=513
# Interface detected at x = 0.50000000, index = 256
# MSE = 3.247451e-02
#  RL2 = 3.016183e-01
# (np.float32(0.032474514), np.float32(0.30161834))
