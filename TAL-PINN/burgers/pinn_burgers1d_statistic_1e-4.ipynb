# %%
import os
import numpy as np

import jax
import jax.numpy as jnp
from jax import jacfwd, vmap
from functools import partial
from typing import NamedTuple, Sequence, Callable

import flax.linen as nn
import optax
from soap_jax import soap

import time
import scipy.io
import matplotlib.pyplot as plt

from flax import serialization

from Utilities_pinn_burgers1d_statistic import *

# %%
# 1. Data
data = scipy.io.loadmat("burgers_godunov.mat")
#data = scipy.io.loadmat("burgers_riemann.mat")

U0 = jnp.asarray(data["U"][::2,::2])
X0 = jnp.asarray(data["X"][::2,::2])
T0 = jnp.asarray(data["T"][::2,::2])

Nt_test, Nx_test = U0.shape
t_test = T0.reshape(-1)
x_test = X0.reshape(-1)
test_inputs = jnp.stack([t_test, x_test], axis=-1)
test_labels = U0.reshape(-1, 1)

x_unique = np.unique(np.asarray(X0))
interface_idx = int(np.argmin(np.abs(x_unique - 0.5)))
interface_x = float(x_unique[interface_idx])

print(f"Test grid: Nt={Nt_test}, Nx={Nx_test}")
print(f"Interface x={interface_x:.8f}, index={interface_idx}")

plt.figure(figsize=(5.5, 4))
plt.contourf(X0, T0, U0, levels=50, cmap='jet')
plt.colorbar(label='U')
plt.xlabel('x')
plt.ylabel('t')
plt.title('U')
plt.tight_layout()
plt.show()
# Out:
# Test grid: Nt=513, Nx=513
# Interface x=0.50000000, index=256

# %%
# 2. Keep the PDE initialization/training keys aligned with TAL-PINN.
seed = 49
key = jax.random.PRNGKey(seed)
key_pde_init, _, key_train = jax.random.split(key, 3)

# 3. Vanilla PINN on physical coordinates [t, x]
pde_net = FNN_fourier(layer_sizes=[40, 40, 1], fourier_dim=20)
pde_params = pde_net.init(key_pde_init, jnp.ones((2,), dtype=T0.dtype))

pde_optimizer = soap(learning_rate=3.0e-3, b1=0.95, b2=0.95, weight_decay=0.01, precondition_frequency=10, precondition_1d=False)

pde_loss_grad_fn = create_pde_loss_grad_fn(pde_net)
pde_minibatch_fn = create_pde_minibatch_fn(IC_Burgers, BC_Burgers)
eval_fn = create_eval_fn(pde_net, nx_test=Nx_test, interface_idx=interface_idx, interface_mode="drop")

# %%
# 4. One direct training stage at the target viscosity.
pde_params, key_train, history = train_pde_stage(stage_name="Vanilla PINN", pde_params=pde_params, pde_optimizer=pde_optimizer, pde_loss_grad_fn=pde_loss_grad_fn, pde_minibatch_fn=pde_minibatch_fn,
    eval_fn=eval_fn, test_inputs=test_inputs, test_labels=test_labels,
    key=key_train, nu=1.0e-4, max_iters=8000, pts_pde=10000, pts_ics=1000, pts_bcs=1000, max_runtime=10000.0, eval_every=100)

save_training_results(pde_params=pde_params, pde_history=history, checkpoint_path="pinn_burgers_statistic10.msgpack")

plot_training_history(history, metric="rl2", title="Vanilla PINN training history")
plot_evaluation(params=pde_params, model=pde_net, t_test=t_test, x_test=x_test, labels_test=test_labels, interface_x=interface_x, 
    metric_interface_mode="drop", plot_interface_mode="none")
# Out:
# [Vanilla PINN] JIT warm-up finished.
# [Vanilla PINN] iter = 00000, time = 0.00s | mse = 1.44e+00, rl2 = 2.43e+00
# [Vanilla PINN] iter = 00100, time = 0.55s, loss = 6.80e-01 | mse = 9.24e-02, rl2 = 6.14e-01
# [Vanilla PINN] iter = 00200, time = 0.84s, loss = 5.01e-01 | mse = 4.93e-02, rl2 = 4.48e-01
# [Vanilla PINN] iter = 00300, time = 1.14s, loss = 4.89e-01 | mse = 4.48e-02, rl2 = 4.27e-01
# [Vanilla PINN] iter = 00400, time = 1.43s, loss = 4.93e-01 | mse = 4.33e-02, rl2 = 4.20e-01
# [Vanilla PINN] iter = 00500, time = 1.73s, loss = 4.95e-01 | mse = 4.26e-02, rl2 = 4.16e-01
# [Vanilla PINN] iter = 00600, time = 2.03s, loss = 4.76e-01 | mse = 4.16e-02, rl2 = 4.11e-01
# [Vanilla PINN] iter = 00700, time = 2.32s, loss = 4.74e-01 | mse = 4.09e-02, rl2 = 4.08e-01
# [Vanilla PINN] iter = 00800, time = 2.62s, loss = 4.79e-01 | mse = 4.14e-02, rl2 = 4.11e-01
# [Vanilla PINN] iter = 00900, time = 2.91s, loss = 4.88e-01 | mse = 4.03e-02, rl2 = 4.05e-01
# [Vanilla PINN] iter = 01000, time = 3.21s, loss = 4.84e-01 | mse = 4.08e-02, rl2 = 4.08e-01
# [Vanilla PINN] iter = 01100, time = 3.51s, loss = 4.82e-01 | mse = 4.00e-02, rl2 = 4.04e-01
# [Vanilla PINN] iter = 01200, time = 3.81s, loss = 4.79e-01 | mse = 4.05e-02, rl2 = 4.06e-01
# [Vanilla PINN] iter = 01300, time = 4.11s, loss = 4.76e-01 | mse = 3.97e-02, rl2 = 4.02e-01
# [Vanilla PINN] iter = 01400, time = 4.40s, loss = 4.74e-01 | mse = 4.05e-02, rl2 = 4.06e-01
# [Vanilla PINN] iter = 01500, time = 4.70s, loss = 4.62e-01 | mse = 3.96e-02, rl2 = 4.02e-01
# [Vanilla PINN] iter = 01600, time = 5.00s, loss = 4.56e-01 | mse = 3.92e-02, rl2 = 4.00e-01
# [Vanilla PINN] iter = 01700, time = 5.30s, loss = 4.66e-01 | mse = 4.02e-02, rl2 = 4.05e-01
# [Vanilla PINN] iter = 01800, time = 5.60s, loss = 4.70e-01 | mse = 3.90e-02, rl2 = 3.99e-01
# [Vanilla PINN] iter = 01900, time = 5.89s, loss = 4.60e-01 | mse = 3.91e-02, rl2 = 3.99e-01
# [Vanilla PINN] iter = 02000, time = 6.19s, loss = 4.70e-01 | mse = 3.92e-02, rl2 = 4.00e-01
# [Vanilla PINN] iter = 02100, time = 6.49s, loss = 4.61e-01 | mse = 3.92e-02, rl2 = 4.00e-01
# [Vanilla PINN] iter = 02200, time = 6.79s, loss = 4.70e-01 | mse = 3.94e-02, rl2 = 4.01e-01
# [Vanilla PINN] iter = 02300, time = 7.09s, loss = 4.72e-01 | mse = 4.03e-02, rl2 = 4.05e-01
# [Vanilla PINN] iter = 02400, time = 7.38s, loss = 4.78e-01 | mse = 3.99e-02, rl2 = 4.03e-01
# [Vanilla PINN] iter = 02500, time = 7.68s, loss = 4.63e-01 | mse = 3.74e-02, rl2 = 3.90e-01
# [Vanilla PINN] iter = 02600, time = 7.98s, loss = 4.65e-01 | mse = 3.78e-02, rl2 = 3.93e-01
# [Vanilla PINN] iter = 02700, time = 8.28s, loss = 4.64e-01 | mse = 3.85e-02, rl2 = 3.96e-01
# [Vanilla PINN] iter = 02800, time = 8.57s, loss = 4.69e-01 | mse = 3.81e-02, rl2 = 3.94e-01
# [Vanilla PINN] iter = 02900, time = 8.87s, loss = 4.61e-01 | mse = 3.87e-02, rl2 = 3.97e-01
# [Vanilla PINN] iter = 03000, time = 9.17s, loss = 4.59e-01 | mse = 3.81e-02, rl2 = 3.94e-01
# [Vanilla PINN] iter = 03100, time = 9.47s, loss = 4.63e-01 | mse = 3.77e-02, rl2 = 3.92e-01
# [Vanilla PINN] iter = 03200, time = 9.76s, loss = 4.64e-01 | mse = 3.70e-02, rl2 = 3.88e-01
# [Vanilla PINN] iter = 03300, time = 10.06s, loss = 4.67e-01 | mse = 3.74e-02, rl2 = 3.90e-01
# [Vanilla PINN] iter = 03400, time = 10.36s, loss = 4.70e-01 | mse = 3.85e-02, rl2 = 3.96e-01
# [Vanilla PINN] iter = 03500, time = 10.66s, loss = 4.75e-01 | mse = 3.83e-02, rl2 = 3.95e-01
# [Vanilla PINN] iter = 03600, time = 10.95s, loss = 4.63e-01 | mse = 3.75e-02, rl2 = 3.91e-01
# [Vanilla PINN] iter = 03700, time = 11.25s, loss = 4.68e-01 | mse = 3.78e-02, rl2 = 3.92e-01
# [Vanilla PINN] iter = 03800, time = 11.54s, loss = 4.68e-01 | mse = 3.77e-02, rl2 = 3.92e-01
# [Vanilla PINN] iter = 03900, time = 11.84s, loss = 4.65e-01 | mse = 3.72e-02, rl2 = 3.89e-01
# [Vanilla PINN] iter = 04000, time = 12.13s, loss = 4.65e-01 | mse = 3.76e-02, rl2 = 3.91e-01
# [Vanilla PINN] iter = 04100, time = 12.43s, loss = 4.67e-01 | mse = 3.90e-02, rl2 = 3.99e-01
# [Vanilla PINN] iter = 04200, time = 12.72s, loss = 4.73e-01 | mse = 3.64e-02, rl2 = 3.85e-01
# [Vanilla PINN] iter = 04300, time = 13.02s, loss = 4.60e-01 | mse = 3.80e-02, rl2 = 3.94e-01
# [Vanilla PINN] iter = 04400, time = 13.31s, loss = 4.64e-01 | mse = 3.72e-02, rl2 = 3.89e-01
# [Vanilla PINN] iter = 04500, time = 13.61s, loss = 4.60e-01 | mse = 3.55e-02, rl2 = 3.80e-01
# [Vanilla PINN] iter = 04600, time = 13.90s, loss = 4.51e-01 | mse = 3.67e-02, rl2 = 3.87e-01
# [Vanilla PINN] iter = 04700, time = 14.20s, loss = 4.60e-01 | mse = 3.56e-02, rl2 = 3.81e-01
# [Vanilla PINN] iter = 04800, time = 14.50s, loss = 4.44e-01 | mse = 4.06e-02, rl2 = 4.07e-01
# [Vanilla PINN] iter = 04900, time = 14.79s, loss = 4.42e-01 | mse = 3.61e-02, rl2 = 3.83e-01
# [Vanilla PINN] iter = 05000, time = 15.09s, loss = 4.50e-01 | mse = 3.52e-02, rl2 = 3.79e-01
# [Vanilla PINN] iter = 05100, time = 15.38s, loss = 4.59e-01 | mse = 4.10e-02, rl2 = 4.09e-01
# [Vanilla PINN] iter = 05200, time = 15.68s, loss = 4.59e-01 | mse = 3.51e-02, rl2 = 3.78e-01
# [Vanilla PINN] iter = 05300, time = 15.97s, loss = 4.74e-01 | mse = 7.19e-02, rl2 = 5.41e-01
# [Vanilla PINN] iter = 05400, time = 16.27s, loss = 4.43e-01 | mse = 5.15e-02, rl2 = 4.58e-01
# [Vanilla PINN] iter = 05500, time = 16.56s, loss = 4.51e-01 | mse = 3.96e-02, rl2 = 4.02e-01
# [Vanilla PINN] iter = 05600, time = 16.86s, loss = 4.30e-01 | mse = 3.93e-02, rl2 = 4.00e-01
# [Vanilla PINN] iter = 05700, time = 17.15s, loss = 4.30e-01 | mse = 3.28e-02, rl2 = 3.66e-01
# [Vanilla PINN] iter = 05800, time = 17.45s, loss = 4.16e-01 | mse = 3.73e-02, rl2 = 3.90e-01
# [Vanilla PINN] iter = 05900, time = 17.74s, loss = 4.30e-01 | mse = 4.93e-02, rl2 = 4.48e-01
# [Vanilla PINN] iter = 06000, time = 18.04s, loss = 4.18e-01 | mse = 3.73e-02, rl2 = 3.90e-01
# [Vanilla PINN] iter = 06100, time = 18.33s, loss = 4.37e-01 | mse = 5.56e-02, rl2 = 4.76e-01
# [Vanilla PINN] iter = 06200, time = 18.63s, loss = 4.44e-01 | mse = 6.17e-02, rl2 = 5.01e-01
# [Vanilla PINN] iter = 06300, time = 18.93s, loss = 4.17e-01 | mse = 3.56e-02, rl2 = 3.81e-01
# [Vanilla PINN] iter = 06400, time = 19.22s, loss = 4.12e-01 | mse = 3.43e-02, rl2 = 3.74e-01
# [Vanilla PINN] iter = 06500, time = 19.52s, loss = 3.99e-01 | mse = 3.92e-02, rl2 = 4.00e-01
# [Vanilla PINN] iter = 06600, time = 19.82s, loss = 4.36e-01 | mse = 7.02e-02, rl2 = 5.35e-01
# [Vanilla PINN] iter = 06700, time = 20.11s, loss = 4.11e-01 | mse = 6.44e-02, rl2 = 5.12e-01
# [Vanilla PINN] iter = 06800, time = 20.41s, loss = 4.36e-01 | mse = 8.05e-02, rl2 = 5.73e-01
# [Vanilla PINN] iter = 06900, time = 20.71s, loss = 3.80e-01 | mse = 4.80e-02, rl2 = 4.42e-01
# [Vanilla PINN] iter = 07000, time = 21.00s, loss = 3.87e-01 | mse = 3.65e-02, rl2 = 3.86e-01
# [Vanilla PINN] iter = 07100, time = 21.30s, loss = 3.66e-01 | mse = 5.40e-02, rl2 = 4.69e-01
# [Vanilla PINN] iter = 07200, time = 21.60s, loss = 3.87e-01 | mse = 7.93e-02, rl2 = 5.68e-01
# [Vanilla PINN] iter = 07300, time = 21.89s, loss = 3.61e-01 | mse = 5.69e-02, rl2 = 4.82e-01
# [Vanilla PINN] iter = 07400, time = 22.19s, loss = 3.55e-01 | mse = 5.66e-02, rl2 = 4.80e-01
# [Vanilla PINN] iter = 07500, time = 22.49s, loss = 3.34e-01 | mse = 3.03e-02, rl2 = 3.51e-01
# [Vanilla PINN] iter = 07600, time = 22.78s, loss = 3.76e-01 | mse = 6.33e-02, rl2 = 5.08e-01
# [Vanilla PINN] iter = 07700, time = 23.08s, loss = 3.63e-01 | mse = 7.26e-02, rl2 = 5.44e-01
# [Vanilla PINN] iter = 07800, time = 23.38s, loss = 3.85e-01 | mse = 7.59e-02, rl2 = 5.56e-01
# [Vanilla PINN] iter = 07900, time = 23.67s, loss = 3.63e-01 | mse = 6.61e-02, rl2 = 5.19e-01
# [Vanilla PINN] iter = 08000, time = 23.97s, loss = 3.11e-01 | mse = 3.64e-02, rl2 = 3.85e-01
# Training checkpoint saved to: /home/DG21210022/Amon/tal/burgers/pinn_burgers_statistic10.msgpack
# Training history saved to: /home/DG21210022/Amon/tal/burgers/pinn_burgers_statistic10_history.npz
# Plotting... Test grid shape: nt=513, nx=513
# Interface detected at x = 0.50000000, index = 256
# MSE = 3.640211e-02
#  RL2 = 3.851395e-01
# (np.float32(0.03640211), np.float32(0.3851395))
