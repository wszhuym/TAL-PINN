# %%
import os
import numpy as np

import jax
import jax.numpy as jnp
from jax import jacfwd, vmap
from functools import partial
from typing import NamedTuple, Sequence, Callable

import flax.linen as nn
import optax
from soap_jax import soap

import time
import scipy.io
import matplotlib.pyplot as plt

from flax import serialization

from Utilities_pinn_burgers1d_moving import *

# %%
# 1. Data
data = scipy.io.loadmat("burgers_godunov2.mat")

#data = scipy.io.loadmat("burgers_riemann.mat")

U0 = jnp.asarray(data["U"][::2,::2])
X0 = jnp.asarray(data["X"][::2,::2])
T0 = jnp.asarray(data["T"][::2,::2])

Nt_test, Nx_test = U0.shape
t_test = T0.reshape(-1)
x_test = X0.reshape(-1)
test_inputs = jnp.stack([t_test, x_test], axis=-1)
test_labels = U0.reshape(-1, 1)

x_unique = np.unique(np.asarray(X0))
interface_idx = int(np.argmin(np.abs(x_unique - 0.5)))
interface_x = float(x_unique[interface_idx])

print(f"Test grid: Nt={Nt_test}, Nx={Nx_test}")
print(f"Interface x={interface_x:.8f}, index={interface_idx}")

plt.figure(figsize=(5.5, 4))
plt.contourf(X0, T0, U0, levels=50, cmap='jet')
plt.colorbar(label='U')
plt.xlabel('x')
plt.ylabel('t')
plt.title('U')
plt.tight_layout()
plt.show()
# Out:
# Test grid: Nt=513, Nx=513
# Interface x=0.50000000, index=256

# %%
# 2. Keep the PDE initialization/training keys aligned with TAL-PINN.
seed = 40
save_path = "pinn_burgers_movinge10.msgpack"

key = jax.random.PRNGKey(seed)
key_pde_init, _, key_train = jax.random.split(key, 3)

# 3. Vanilla PINN on physical coordinates [t, x]
pde_net = FNN_fourier(layer_sizes=[40, 40, 1], fourier_dim=20)
pde_params = pde_net.init(key_pde_init, jnp.ones((2,), dtype=T0.dtype))

pde_optimizer = soap(learning_rate=3.0e-3, b1=0.95, b2=0.95, weight_decay=0.01, precondition_frequency=10, precondition_1d=False)

pde_loss_grad_fn = create_pde_loss_grad_fn(pde_net)
pde_minibatch_fn = create_pde_minibatch_fn(IC_Burgers, BC_Burgers)
eval_fn = create_eval_fn(pde_net, nx_test=Nx_test, interface_idx=interface_idx, interface_mode="drop")

# %%
# 4. One direct training stage at the target viscosity.
pde_params, key_train, history = train_pde_stage(stage_name="Vanilla PINN", pde_params=pde_params, pde_optimizer=pde_optimizer, pde_loss_grad_fn=pde_loss_grad_fn, pde_minibatch_fn=pde_minibatch_fn,
    eval_fn=eval_fn, test_inputs=test_inputs, test_labels=test_labels,
    key=key_train, nu=1.0e-3, max_iters=8000, pts_pde=10000, pts_ics=1000, pts_bcs=1000, max_runtime=10000.0, eval_every=100)

save_training_results(pde_params=pde_params, pde_history=history, checkpoint_path=save_path)

plot_training_history(history, metric="rl2", title="Vanilla PINN training history")
plot_evaluation(params=pde_params, model=pde_net, t_test=t_test, x_test=x_test, labels_test=test_labels, interface_x=interface_x, 
    metric_interface_mode="drop", plot_interface_mode="none")
# Out:
# [Vanilla PINN] JIT warm-up finished.
# [Vanilla PINN] iter = 00000, time = 0.00s | mse = 5.62e-01, rl2 = 1.25e+00
# [Vanilla PINN] iter = 00100, time = 0.56s, loss = 6.16e-01 | mse = 6.32e-02, rl2 = 4.21e-01
# [Vanilla PINN] iter = 00200, time = 0.85s, loss = 5.41e-01 | mse = 5.38e-02, rl2 = 3.88e-01
# [Vanilla PINN] iter = 00300, time = 1.15s, loss = 5.16e-01 | mse = 4.96e-02, rl2 = 3.73e-01
# [Vanilla PINN] iter = 00400, time = 1.44s, loss = 4.96e-01 | mse = 4.68e-02, rl2 = 3.62e-01
# [Vanilla PINN] iter = 00500, time = 1.74s, loss = 4.90e-01 | mse = 4.54e-02, rl2 = 3.57e-01
# [Vanilla PINN] iter = 00600, time = 2.04s, loss = 4.84e-01 | mse = 4.38e-02, rl2 = 3.50e-01
# [Vanilla PINN] iter = 00700, time = 2.33s, loss = 4.77e-01 | mse = 4.15e-02, rl2 = 3.41e-01
# [Vanilla PINN] iter = 00800, time = 2.62s, loss = 4.72e-01 | mse = 4.02e-02, rl2 = 3.36e-01
# [Vanilla PINN] iter = 00900, time = 2.92s, loss = 4.56e-01 | mse = 3.93e-02, rl2 = 3.32e-01
# [Vanilla PINN] iter = 01000, time = 3.21s, loss = 4.51e-01 | mse = 3.88e-02, rl2 = 3.30e-01
# [Vanilla PINN] iter = 01100, time = 3.51s, loss = 4.39e-01 | mse = 3.69e-02, rl2 = 3.21e-01
# [Vanilla PINN] iter = 01200, time = 3.80s, loss = 4.40e-01 | mse = 3.41e-02, rl2 = 3.09e-01
# [Vanilla PINN] iter = 01300, time = 4.10s, loss = 4.15e-01 | mse = 3.18e-02, rl2 = 2.99e-01
# [Vanilla PINN] iter = 01400, time = 4.40s, loss = 3.69e-01 | mse = 2.69e-02, rl2 = 2.75e-01
# [Vanilla PINN] iter = 01500, time = 4.69s, loss = 3.23e-01 | mse = 2.42e-02, rl2 = 2.61e-01
# [Vanilla PINN] iter = 01600, time = 4.99s, loss = 2.66e-01 | mse = 1.94e-02, rl2 = 2.33e-01
# [Vanilla PINN] iter = 01700, time = 5.28s, loss = 1.92e-01 | mse = 2.36e-02, rl2 = 2.57e-01
# [Vanilla PINN] iter = 01800, time = 5.57s, loss = 1.39e-01 | mse = 1.67e-02, rl2 = 2.16e-01
# [Vanilla PINN] iter = 01900, time = 5.86s, loss = 1.01e-01 | mse = 2.27e-02, rl2 = 2.52e-01
# [Vanilla PINN] iter = 02000, time = 6.15s, loss = 8.08e-02 | mse = 1.51e-02, rl2 = 2.06e-01
# [Vanilla PINN] iter = 02100, time = 6.45s, loss = 6.79e-02 | mse = 1.53e-02, rl2 = 2.07e-01
# [Vanilla PINN] iter = 02200, time = 6.74s, loss = 6.78e-02 | mse = 2.24e-02, rl2 = 2.51e-01
# [Vanilla PINN] iter = 02300, time = 7.03s, loss = 5.39e-02 | mse = 2.38e-02, rl2 = 2.58e-01
# [Vanilla PINN] iter = 02400, time = 7.32s, loss = 5.85e-02 | mse = 6.86e-03, rl2 = 1.39e-01
# [Vanilla PINN] iter = 02500, time = 7.62s, loss = 4.67e-02 | mse = 1.28e-02, rl2 = 1.89e-01
# [Vanilla PINN] iter = 02600, time = 7.91s, loss = 4.28e-02 | mse = 2.55e-03, rl2 = 8.46e-02
# [Vanilla PINN] iter = 02700, time = 8.21s, loss = 3.26e-02 | mse = 8.92e-03, rl2 = 1.58e-01
# [Vanilla PINN] iter = 02800, time = 8.50s, loss = 3.32e-02 | mse = 9.28e-03, rl2 = 1.61e-01
# [Vanilla PINN] iter = 02900, time = 8.80s, loss = 3.45e-02 | mse = 2.22e-03, rl2 = 7.89e-02
# [Vanilla PINN] iter = 03000, time = 9.09s, loss = 2.46e-02 | mse = 1.94e-03, rl2 = 7.36e-02
# [Vanilla PINN] iter = 03100, time = 9.38s, loss = 1.95e-02 | mse = 3.66e-03, rl2 = 1.01e-01
# [Vanilla PINN] iter = 03200, time = 9.67s, loss = 2.29e-02 | mse = 3.73e-03, rl2 = 1.02e-01
# [Vanilla PINN] iter = 03300, time = 9.97s, loss = 2.47e-02 | mse = 4.92e-03, rl2 = 1.17e-01
# [Vanilla PINN] iter = 03400, time = 10.26s, loss = 2.34e-02 | mse = 1.99e-02, rl2 = 2.36e-01
# [Vanilla PINN] iter = 03500, time = 10.55s, loss = 2.40e-02 | mse = 5.32e-03, rl2 = 1.22e-01
# [Vanilla PINN] iter = 03600, time = 10.85s, loss = 1.72e-02 | mse = 6.68e-03, rl2 = 1.37e-01
# [Vanilla PINN] iter = 03700, time = 11.14s, loss = 1.94e-02 | mse = 2.53e-03, rl2 = 8.41e-02
# [Vanilla PINN] iter = 03800, time = 11.44s, loss = 1.95e-02 | mse = 6.03e-03, rl2 = 1.30e-01
# [Vanilla PINN] iter = 03900, time = 11.74s, loss = 1.68e-02 | mse = 2.56e-03, rl2 = 8.48e-02
# [Vanilla PINN] iter = 04000, time = 12.04s, loss = 1.97e-02 | mse = 5.88e-03, rl2 = 1.28e-01
# [Vanilla PINN] iter = 04100, time = 12.33s, loss = 1.99e-02 | mse = 2.96e-03, rl2 = 9.11e-02
# [Vanilla PINN] iter = 04200, time = 12.63s, loss = 1.04e-02 | mse = 1.00e-03, rl2 = 5.30e-02
# [Vanilla PINN] iter = 04300, time = 12.92s, loss = 1.33e-02 | mse = 1.43e-03, rl2 = 6.34e-02
# [Vanilla PINN] iter = 04400, time = 13.22s, loss = 8.97e-03 | mse = 4.93e-03, rl2 = 1.18e-01
# [Vanilla PINN] iter = 04500, time = 13.51s, loss = 1.09e-02 | mse = 3.06e-03, rl2 = 9.26e-02
# [Vanilla PINN] iter = 04600, time = 13.81s, loss = 8.97e-03 | mse = 2.35e-03, rl2 = 8.12e-02
# [Vanilla PINN] iter = 04700, time = 14.10s, loss = 1.06e-02 | mse = 4.02e-03, rl2 = 1.06e-01
# [Vanilla PINN] iter = 04800, time = 14.40s, loss = 1.13e-02 | mse = 2.83e-03, rl2 = 8.90e-02
# [Vanilla PINN] iter = 04900, time = 14.69s, loss = 9.81e-03 | mse = 2.02e-03, rl2 = 7.52e-02
# [Vanilla PINN] iter = 05000, time = 14.99s, loss = 1.09e-02 | mse = 7.49e-03, rl2 = 1.45e-01
# [Vanilla PINN] iter = 05100, time = 15.28s, loss = 9.42e-03 | mse = 9.99e-04, rl2 = 5.29e-02
# [Vanilla PINN] iter = 05200, time = 15.58s, loss = 8.59e-03 | mse = 5.85e-03, rl2 = 1.28e-01
# [Vanilla PINN] iter = 05300, time = 15.87s, loss = 8.16e-03 | mse = 1.19e-03, rl2 = 5.76e-02
# [Vanilla PINN] iter = 05400, time = 16.17s, loss = 6.51e-03 | mse = 1.65e-03, rl2 = 6.79e-02
# [Vanilla PINN] iter = 05500, time = 16.46s, loss = 7.73e-03 | mse = 1.78e-03, rl2 = 7.07e-02
# [Vanilla PINN] iter = 05600, time = 16.76s, loss = 5.93e-03 | mse = 1.02e-03, rl2 = 5.35e-02
# [Vanilla PINN] iter = 05700, time = 17.05s, loss = 4.57e-03 | mse = 1.26e-03, rl2 = 5.93e-02
# [Vanilla PINN] iter = 05800, time = 17.35s, loss = 6.68e-03 | mse = 8.05e-04, rl2 = 4.75e-02
# [Vanilla PINN] iter = 05900, time = 17.64s, loss = 7.20e-03 | mse = 1.31e-03, rl2 = 6.06e-02
# [Vanilla PINN] iter = 06000, time = 17.94s, loss = 8.56e-03 | mse = 2.32e-03, rl2 = 8.06e-02
# [Vanilla PINN] iter = 06100, time = 18.23s, loss = 6.89e-03 | mse = 8.08e-04, rl2 = 4.76e-02
# [Vanilla PINN] iter = 06200, time = 18.53s, loss = 7.40e-03 | mse = 7.94e-03, rl2 = 1.49e-01
# [Vanilla PINN] iter = 06300, time = 18.83s, loss = 6.06e-03 | mse = 9.79e-04, rl2 = 5.24e-02
# [Vanilla PINN] iter = 06400, time = 19.12s, loss = 9.59e-03 | mse = 7.23e-03, rl2 = 1.42e-01
# [Vanilla PINN] iter = 06500, time = 19.42s, loss = 3.61e-03 | mse = 7.54e-04, rl2 = 4.60e-02
# [Vanilla PINN] iter = 06600, time = 19.71s, loss = 4.76e-03 | mse = 9.09e-04, rl2 = 5.05e-02
# [Vanilla PINN] iter = 06700, time = 20.01s, loss = 6.51e-03 | mse = 7.59e-04, rl2 = 4.61e-02
# [Vanilla PINN] iter = 06800, time = 20.30s, loss = 3.86e-03 | mse = 1.14e-03, rl2 = 5.66e-02
# [Vanilla PINN] iter = 06900, time = 20.60s, loss = 6.22e-03 | mse = 1.82e-03, rl2 = 7.14e-02
# [Vanilla PINN] iter = 07000, time = 20.90s, loss = 6.18e-03 | mse = 1.14e-03, rl2 = 5.65e-02
# [Vanilla PINN] iter = 07100, time = 21.19s, loss = 5.16e-03 | mse = 8.04e-04, rl2 = 4.75e-02
# [Vanilla PINN] iter = 07200, time = 21.48s, loss = 3.68e-03 | mse = 8.07e-04, rl2 = 4.75e-02
# [Vanilla PINN] iter = 07300, time = 21.78s, loss = 6.69e-03 | mse = 1.06e-03, rl2 = 5.45e-02
# [Vanilla PINN] iter = 07400, time = 22.07s, loss = 5.37e-03 | mse = 9.19e-04, rl2 = 5.07e-02
# [Vanilla PINN] iter = 07500, time = 22.37s, loss = 4.02e-03 | mse = 2.30e-03, rl2 = 8.02e-02
# [Vanilla PINN] iter = 07600, time = 22.67s, loss = 5.67e-03 | mse = 4.20e-03, rl2 = 1.09e-01
# [Vanilla PINN] iter = 07700, time = 22.96s, loss = 3.80e-03 | mse = 9.32e-04, rl2 = 5.11e-02
# [Vanilla PINN] iter = 07800, time = 23.26s, loss = 5.67e-03 | mse = 2.15e-03, rl2 = 7.77e-02
# [Vanilla PINN] iter = 07900, time = 23.55s, loss = 3.06e-03 | mse = 9.01e-04, rl2 = 5.03e-02
# [Vanilla PINN] iter = 08000, time = 23.85s, loss = 4.57e-03 | mse = 1.20e-03, rl2 = 5.79e-02
# Training checkpoint saved to: /home/DG21210022/Amon/tal/burgers/pinn_burgers_movinge10.msgpack
# Training history saved to: /home/DG21210022/Amon/tal/burgers/pinn_burgers_movinge10_history.npz
# Plotting... Test grid shape: nt=513, nx=513
# Interface detected at x = 0.50000000, index = 256
# MSE = 1.196479e-03
#  RL2 = 5.789473e-02
# (np.float32(0.0011964793), np.float32(0.057894733))
