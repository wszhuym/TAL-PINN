# %%
import os
import numpy as np

import jax
import jax.numpy as jnp
from jax import jacfwd, vmap
from functools import partial
from typing import NamedTuple, Sequence, Callable

import flax.linen as nn
import optax
from soap_jax import soap

import time
import scipy.io
import matplotlib.pyplot as plt

from flax import serialization

from Utilities_talpinn_euler1d import *

# %%
# 1. Load Sod shock-tube data
path = "SodShocktube_data.mat"
#path = "LaxShocktube_data.mat"
data = scipy.io.loadmat(path)

sss = 8
Rho0 = jnp.asarray(data["Rho"])[:, ::sss]
U0 = jnp.asarray(data["U"])[:, ::sss]
P0 = jnp.asarray(data["P"])[:, ::sss]
X0 = jnp.asarray(data["X"])[:, ::sss]
T0 = jnp.asarray(data["T"])[:, ::sss]

Nt_test, Nx_test = Rho0.shape
xl = float(X0[0, 0])
xr = float(X0[0, -1])
t0 = float(T0[0, 0])
tend = float(T0[-1, 0])

x_jump = 0.5 * (xl + xr)
ic_params = (float(Rho0[0, 0]), float(U0[0, 0]), float(P0[0, 0]), float(Rho0[0, -1]), float(U0[0, -1]), float(P0[0, -1]))
left_state = ic_params[:3]
right_state = ic_params[3:]

trange = (t0, tend)
xrange = (xl, xr)

T_grid = T0
X_grid = X0

t_test = T0.reshape(-1)
x_test = X0.reshape(-1)

test_labels = jnp.stack([Rho0.reshape(-1), U0.reshape(-1),P0.reshape(-1)], axis=-1)

print(f"Test grid: Nt={Nt_test}, Nx={Nx_test}")
print(f"Time domain: {trange}")
print(f"Space domain: {xrange}")
print(f"Interface position: {x_jump}")
print(f"Left state  [rho,u,p]: {left_state}")
print(f"Right state [rho,u,p]: {right_state}")
# Out:
# Test grid: Nt=129, Nx=257
# Time domain: (0.0, 0.20000000298023224)
# Space domain: (0.0, 1.0)
# Interface position: 0.5
# Left state  [rho,u,p]: (1.0, 0.0, 1.0)
# Right state [rho,u,p]: (0.125, 0.0, 0.10000000149011612)

# %%
# 2. Random keys
seed = 47

save_path = "talpinn_sod03.msgpack"

key = jax.random.PRNGKey(seed)
key_pde_init, key_coor_init, key_train = jax.random.split(key, 3)

# 3. Models
pde_net = Euler_net(n_nodes=40, fourier_dim=20, activation=nn.silu)
pde_params = pde_net.init(key_pde_init, jnp.ones((3,), dtype=T0.dtype))
coor_net = FNN_fourier(layer_sizes=[40, 40, 1], activation=nn.silu, fourier_dim=20)
coor_params = coor_net.init(key_coor_init, jnp.ones((2,), dtype=T0.dtype))

# 4. Optimizers
pde_optimizer = soap(learning_rate=3.0e-3, b1=0.95, b2=0.95, weight_decay=0.01, precondition_frequency=10, precondition_1d=False)
coor_optimizer = soap(learning_rate=3.0e-3, b1=0.95, b2=0.95, weight_decay=0.01, precondition_frequency=10, precondition_1d=False)

# 5. Common functions
pde_loss_grad_fn = create_pde_loss_grad_fn(pde_net, w_ic=100.0, gamma=1.4)
coor_loss_grad_fn = create_coor_loss_grad_fn(coor_net, lambda_pos=0.1, xi_x_min=0.05)
eval_fn = create_eval_fn(pde_net)

# Initial affine coordinate mapping
identity_map_xi_to_x, identity_coor_fn = create_identity_maps(xl, xr)

def make_minibatch(map_xi_to_x, coor_fn):
    return create_pde_minibatch_fn(IC_map=IC_vmap, map_xi_to_x=map_xi_to_x, coor_net=coor_fn,
        xL=xl, xR=xr, t0=t0, tend=tend, left_state=left_state, right_state=right_state, x_jump=x_jump)

# %%
test_inputs_stage1 = create_test_inputs(t_test, x_test, identity_coor_fn)
minibatch_stage1 = make_minibatch(identity_map_xi_to_x, identity_coor_fn)

pde_params, key_train, history_stage1 = train_pde_stage(stage_name="Stage 1", 
pde_params=pde_params, pde_optimizer=pde_optimizer, pde_loss_grad_fn=pde_loss_grad_fn, pde_minibatch_fn=minibatch_stage1,
eval_fn=eval_fn, test_inputs=test_inputs_stage1,  test_labels=test_labels,
key=key_train, nu=1.0e-3, max_iters=10000, pts_pde=10000, pts_ics=1000, max_runtime=10000.0, eval_every=100)
pde_params_stage1 = pde_params

plot_training_history(history_stage1, metric="rl2", title="Stage 1 training history")
plot_evaluation(params=pde_params, model=pde_net, t_test=t_test, x_test=x_test, labels_test=test_labels, coor_fn=identity_coor_fn)
# Out:
# [Stage 1] JIT warm-up finished.
# [Stage 1] iter=00000, time=0.00s | MSE(rho,u,p)=(6.64e-01, 3.75e-01, 4.97e-01) | RL2(rho,u,p)=(1.19e+00, 1.41e+00, 1.06e+00)
# [Stage 1] iter=00100, time=1.52s, loss=2.77e+00 | MSE(rho,u,p)=(1.51e-02, 4.91e-02, 1.19e-02) | RL2(rho,u,p)=(1.80e-01, 5.11e-01, 1.64e-01)
# [Stage 1] iter=00200, time=2.78s, loss=1.06e+00 | MSE(rho,u,p)=(2.76e-03, 3.63e-02, 3.06e-03) | RL2(rho,u,p)=(7.70e-02, 4.39e-01, 8.28e-02)
# [Stage 1] iter=00300, time=4.04s, loss=7.77e-01 | MSE(rho,u,p)=(1.86e-03, 3.27e-02, 2.27e-03) | RL2(rho,u,p)=(6.32e-02, 4.17e-01, 7.14e-02)
# [Stage 1] iter=00400, time=5.30s, loss=3.84e-01 | MSE(rho,u,p)=(1.52e-03, 3.02e-02, 1.61e-03) | RL2(rho,u,p)=(5.71e-02, 4.01e-01, 6.01e-02)
# [Stage 1] iter=00500, time=6.56s, loss=2.18e-01 | MSE(rho,u,p)=(1.28e-03, 2.60e-02, 1.33e-03) | RL2(rho,u,p)=(5.25e-02, 3.72e-01, 5.47e-02)
# [Stage 1] iter=00600, time=7.81s, loss=3.21e-01 | MSE(rho,u,p)=(1.07e-03, 2.50e-02, 1.15e-03) | RL2(rho,u,p)=(4.79e-02, 3.65e-01, 5.08e-02)
# [Stage 1] iter=00700, time=9.07s, loss=4.52e-01 | MSE(rho,u,p)=(1.02e-03, 2.43e-02, 1.06e-03) | RL2(rho,u,p)=(4.67e-02, 3.60e-01, 4.87e-02)
# [Stage 1] iter=00800, time=10.34s, loss=2.72e-01 | MSE(rho,u,p)=(8.29e-04, 2.20e-02, 9.22e-04) | RL2(rho,u,p)=(4.22e-02, 3.42e-01, 4.55e-02)
# [Stage 1] iter=09400, time=118.70s, loss=2.01e-02 | MSE(rho,u,p)=(2.14e-04, 1.07e-03, 2.17e-04) | RL2(rho,u,p)=(2.15e-02, 7.56e-02, 2.20e-02)
# [Stage 1] iter=09500, time=119.96s, loss=9.73e-02 | MSE(rho,u,p)=(2.93e-04, 2.37e-03, 2.99e-04) | RL2(rho,u,p)=(2.51e-02, 1.12e-01, 2.59e-02)
# [Stage 1] iter=09600, time=121.22s, loss=1.16e-01 | MSE(rho,u,p)=(4.59e-04, 5.24e-03, 5.14e-04) | RL2(rho,u,p)=(3.14e-02, 1.67e-01, 3.40e-02)
# [Stage 1] iter=09700, time=122.48s, loss=1.97e-01 | MSE(rho,u,p)=(2.24e-04, 1.44e-03, 2.25e-04) | RL2(rho,u,p)=(2.19e-02, 8.75e-02, 2.25e-02)
# [Stage 1] iter=09800, time=123.74s, loss=6.04e-02 | MSE(rho,u,p)=(2.49e-04, 1.28e-03, 2.51e-04) | RL2(rho,u,p)=(2.31e-02, 8.26e-02, 2.37e-02)
# [Stage 1] iter=09900, time=125.00s, loss=1.40e-01 | MSE(rho,u,p)=(2.37e-04, 1.58e-03, 2.41e-04) | RL2(rho,u,p)=(2.26e-02, 9.16e-02, 2.32e-02)
# [Stage 1] iter=10000, time=126.26s, loss=5.90e-02 | MSE(rho,u,p)=(2.40e-04, 1.21e-03, 2.34e-04) | RL2(rho,u,p)=(2.27e-02, 8.01e-02, 2.29e-02)
# Plotting test grid: nt=129, nx=257
# Evaluation errors:
#   rho: MSE=2.403555e-04, RL2=2.272291e-02
#   u  : MSE=1.205604e-03, RL2=8.008563e-02
#   p  : MSE=2.338268e-04, RL2=2.290952e-02
# (array([0.00024036, 0.0012056 , 0.00023383], dtype=float32),
#  array([0.02272291, 0.08008563, 0.02290952], dtype=float32))

# %%
# Generate first adaptive mesh
xi_grid, Xi_of_x, X_adapt, map_xi_to_x, solution_stage1 = generate_adaptive_mesh(pde_net=pde_net, pde_params=pde_params, T_grid=T_grid, X_grid=X_grid, coor_fn=identity_coor_fn,
    mesh_method='integral', winslow_tol=1.0e-5, winslow_max_iter=100000, smooth_steps=4)

# Train first coordinate network
coor_params, key_train = train_coordinate_net(coor_net=coor_net, coor_params=coor_params, coor_optimizer=coor_optimizer, coor_loss_grad_fn=coor_loss_grad_fn, T_grid=T_grid, X_grid=X_grid, Xi_of_x=Xi_of_x,
    key=key_train, max_iters=10000, batch_size=10000, eval_every=1000)
coor_params_stage1 = coor_params

trained_coor_fn = create_coor_fn(coor_net, coor_params)

plot_coordinate_mapping(T_grid=T_grid, X_grid=X_grid, xi_grid=xi_grid, Xi_of_x=Xi_of_x, X_adapt=X_adapt, coor_fn=trained_coor_fn, n_times=6)
# Out:
# [Adaptive Mesh] method=integral, time=1.17s
# [Coordinate] JIT warm-up finished.
# [Coordinate] iter=01000, time=2.06s, batch loss=1.67e-05, full mse=1.80e-05
# [Coordinate] iter=02000, time=4.09s, batch loss=8.44e-06, full mse=8.07e-06
# [Coordinate] iter=03000, time=6.12s, batch loss=5.19e-06, full mse=4.84e-06
# [Coordinate] iter=04000, time=8.14s, batch loss=4.09e-06, full mse=4.92e-06
# [Coordinate] iter=05000, time=10.17s, batch loss=3.11e-06, full mse=2.86e-06
# [Coordinate] iter=06000, time=12.20s, batch loss=2.15e-06, full mse=3.83e-06
# [Coordinate] iter=07000, time=14.22s, batch loss=2.83e-06, full mse=3.81e-06
# [Coordinate] iter=08000, time=16.24s, batch loss=4.14e-06, full mse=3.11e-06
# [Coordinate] iter=09000, time=18.27s, batch loss=2.28e-06, full mse=2.59e-06
# [Coordinate] iter=10000, time=20.29s, batch loss=2.32e-06, full mse=2.69e-06
# Coordinate MSE = 2.690564e-06
# Coordinate max error = 3.323931e-02
# xi_x min = 2.650556e-02
# xi_x max = 2.037164e+01
# negative xi_x points = 0

# %%
# Stage 2: first adaptive coordinate, nu=1e-3
test_inputs_stage2 = create_test_inputs(t_test, x_test, trained_coor_fn)
minibatch_stage2 = make_minibatch(map_xi_to_x, trained_coor_fn)

pde_params, key_train, history_stage2 = train_pde_stage(stage_name="Stage 2", 
    pde_params=pde_params, pde_optimizer=pde_optimizer, pde_loss_grad_fn=pde_loss_grad_fn, pde_minibatch_fn=minibatch_stage2,
    eval_fn=eval_fn, test_inputs=test_inputs_stage2,  test_labels=test_labels,
    key=key_train, nu=1.0e-4, max_iters=10000, pts_pde=10000, pts_ics=1000, max_runtime=10000.0, eval_every=100)
pde_params_stage2 = pde_params

plot_training_history(history_stage2, metric="rl2", title="Stage 2 training history",)

plot_evaluation(params=pde_params, model=pde_net, t_test=t_test, x_test=x_test, labels_test=test_labels, coor_fn=trained_coor_fn)
# Out:
# [Stage 2] JIT warm-up finished.
# [Stage 2] iter=00000, time=0.00s | MSE(rho,u,p)=(2.67e-02, 6.20e-02, 2.72e-02) | RL2(rho,u,p)=(2.39e-01, 5.75e-01, 2.47e-01)
# [Stage 2] iter=00100, time=1.37s, loss=7.35e+00 | MSE(rho,u,p)=(8.90e-03, 1.01e-01, 1.77e-02) | RL2(rho,u,p)=(1.38e-01, 7.32e-01, 1.99e-01)
# [Stage 2] iter=00200, time=2.73s, loss=1.21e+00 | MSE(rho,u,p)=(4.13e-03, 1.62e-02, 2.51e-03) | RL2(rho,u,p)=(9.42e-02, 2.93e-01, 7.50e-02)
# [Stage 2] iter=00300, time=4.09s, loss=6.48e-01 | MSE(rho,u,p)=(1.34e-03, 1.08e-02, 1.23e-03) | RL2(rho,u,p)=(5.37e-02, 2.40e-01, 5.26e-02)
# [Stage 2] iter=00400, time=5.45s, loss=5.24e-01 | MSE(rho,u,p)=(6.82e-04, 6.48e-03, 6.89e-04) | RL2(rho,u,p)=(3.83e-02, 1.86e-01, 3.93e-02)
# [Stage 2] iter=00500, time=6.81s, loss=4.26e-01 | MSE(rho,u,p)=(5.52e-04, 5.65e-03, 5.12e-04) | RL2(rho,u,p)=(3.44e-02, 1.73e-01, 3.39e-02)
# [Stage 2] iter=00600, time=8.17s, loss=2.49e-01 | MSE(rho,u,p)=(4.41e-04, 5.32e-03, 3.94e-04) | RL2(rho,u,p)=(3.08e-02, 1.68e-01, 2.97e-02)
# [Stage 2] iter=00700, time=9.53s, loss=2.68e-01 | MSE(rho,u,p)=(3.68e-04, 4.96e-03, 3.87e-04) | RL2(rho,u,p)=(2.81e-02, 1.62e-01, 2.95e-02)
# [Stage 2] iter=00800, time=10.88s, loss=2.29e-01 | MSE(rho,u,p)=(3.39e-04, 5.63e-03, 3.20e-04) | RL2(rho,u,p)=(2.70e-02, 1.73e-01, 2.68e-02)
# [Stage 2] iter=00900, time=12.24s, loss=3.09e-01 | MSE(rho,u,p)=(3.59e-04, 5.04e-03, 3.58e-04) | RL2(rho,u,p)=(2.78e-02, 1.64e-01, 2.84e-02)
# [Stage 2] iter=01000, time=13.59s, loss=3.17e-01 | MSE(rho,u,p)=(3.46e-04, 5.52e-03, 3.12e-04) | RL2(rho,u,p)=(2.73e-02, 1.71e-01, 2.65e-02)
# [Stage 2] iter=01100, time=14.95s, loss=1.52e-01 | MSE(rho,u,p)=(3.49e-04, 5.31e-03, 3.07e-04) | RL2(rho,u,p)=(2.74e-02, 1.68e-01, 2.62e-02)
# [Stage 2] iter=01200, time=16.31s, loss=1.67e-01 | MSE(rho,u,p)=(3.27e-04, 6.00e-03, 2.98e-04) | RL2(rho,u,p)=(2.65e-02, 1.79e-01, 2.59e-02)
# [Stage 2] iter=01300, time=17.66s, loss=2.62e-01 | MSE(rho,u,p)=(3.09e-04, 6.27e-03, 2.87e-04) | RL2(rho,u,p)=(2.58e-02, 1.83e-01, 2.54e-02)
# [Stage 2] iter=01400, time=19.02s, loss=2.29e-01 | MSE(rho,u,p)=(3.62e-04, 5.91e-03, 2.85e-04) | RL2(rho,u,p)=(2.79e-02, 1.77e-01, 2.53e-02)
# [Stage 2] iter=01500, time=20.32s, loss=2.23e-01 | MSE(rho,u,p)=(3.23e-04, 6.14e-03, 2.75e-04) | RL2(rho,u,p)=(2.63e-02, 1.81e-01, 2.49e-02)
# [Stage 2] iter=01600, time=21.60s, loss=2.35e-01 | MSE(rho,u,p)=(3.16e-04, 5.92e-03, 2.86e-04) | RL2(rho,u,p)=(2.61e-02, 1.77e-01, 2.53e-02)
# [Stage 2] iter=01700, time=22.87s, loss=1.41e-01 | MSE(rho,u,p)=(2.90e-04, 6.45e-03, 2.64e-04) | RL2(rho,u,p)=(2.50e-02, 1.85e-01, 2.43e-02)
# [Stage 2] iter=01800, time=24.15s, loss=1.61e-01 | MSE(rho,u,p)=(3.18e-04, 6.53e-03, 2.73e-04) | RL2(rho,u,p)=(2.61e-02, 1.86e-01, 2.48e-02)
# [Stage 2] iter=01900, time=25.43s, loss=2.93e-01 | MSE(rho,u,p)=(3.23e-04, 6.53e-03, 2.61e-04) | RL2(rho,u,p)=(2.63e-02, 1.86e-01, 2.42e-02)
# [Stage 2] iter=02000, time=26.71s, loss=1.93e-01 | MSE(rho,u,p)=(2.88e-04, 6.72e-03, 2.72e-04) | RL2(rho,u,p)=(2.49e-02, 1.89e-01, 2.47e-02)
# [Stage 2] iter=02100, time=27.98s, loss=1.01e-01 | MSE(rho,u,p)=(2.87e-04, 6.37e-03, 2.63e-04) | RL2(rho,u,p)=(2.48e-02, 1.84e-01, 2.43e-02)
# [Stage 2] iter=02200, time=29.26s, loss=1.63e-01 | MSE(rho,u,p)=(3.10e-04, 6.34e-03, 2.60e-04) | RL2(rho,u,p)=(2.58e-02, 1.84e-01, 2.41e-02)
# [Stage 2] iter=02300, time=30.54s, loss=2.08e-01 | MSE(rho,u,p)=(3.31e-04, 6.32e-03, 2.66e-04) | RL2(rho,u,p)=(2.67e-02, 1.83e-01, 2.44e-02)
# [Stage 2] iter=02400, time=31.82s, loss=1.52e-01 | MSE(rho,u,p)=(3.05e-04, 6.93e-03, 2.87e-04) | RL2(rho,u,p)=(2.56e-02, 1.92e-01, 2.54e-02)
# [Stage 2] iter=02500, time=33.09s, loss=1.29e-01 | MSE(rho,u,p)=(2.88e-04, 6.90e-03, 2.78e-04) | RL2(rho,u,p)=(2.49e-02, 1.92e-01, 2.50e-02)
# [Stage 2] iter=02600, time=34.37s, loss=2.59e-01 | MSE(rho,u,p)=(3.21e-04, 6.48e-03, 2.83e-04) | RL2(rho,u,p)=(2.63e-02, 1.86e-01, 2.52e-02)
# [Stage 2] iter=02700, time=35.65s, loss=1.85e-01 | MSE(rho,u,p)=(3.11e-04, 6.24e-03, 2.64e-04) | RL2(rho,u,p)=(2.59e-02, 1.82e-01, 2.44e-02)
# [Stage 2] iter=02800, time=36.92s, loss=2.10e-01 | MSE(rho,u,p)=(3.25e-04, 6.90e-03, 3.03e-04) | RL2(rho,u,p)=(2.64e-02, 1.92e-01, 2.61e-02)
# [Stage 2] iter=02900, time=38.20s, loss=4.34e-01 | MSE(rho,u,p)=(3.21e-04, 6.15e-03, 2.63e-04) | RL2(rho,u,p)=(2.62e-02, 1.81e-01, 2.43e-02)
# [Stage 2] iter=03000, time=39.48s, loss=2.31e-01 | MSE(rho,u,p)=(3.34e-04, 6.60e-03, 2.72e-04) | RL2(rho,u,p)=(2.68e-02, 1.87e-01, 2.47e-02)
# [Stage 2] iter=03100, time=40.76s, loss=2.06e-01 | MSE(rho,u,p)=(3.31e-04, 6.95e-03, 2.83e-04) | RL2(rho,u,p)=(2.67e-02, 1.92e-01, 2.52e-02)
# [Stage 2] iter=03200, time=42.04s, loss=2.15e-01 | MSE(rho,u,p)=(2.96e-04, 7.04e-03, 2.74e-04) | RL2(rho,u,p)=(2.52e-02, 1.94e-01, 2.48e-02)
# [Stage 2] iter=03300, time=43.31s, loss=1.08e-01 | MSE(rho,u,p)=(2.83e-04, 6.99e-03, 2.68e-04) | RL2(rho,u,p)=(2.47e-02, 1.93e-01, 2.45e-02)
# [Stage 2] iter=03400, time=44.59s, loss=2.19e-01 | MSE(rho,u,p)=(3.66e-04, 7.07e-03, 3.20e-04) | RL2(rho,u,p)=(2.80e-02, 1.94e-01, 2.68e-02)
# [Stage 2] iter=03500, time=45.87s, loss=2.00e-01 | MSE(rho,u,p)=(2.81e-04, 6.62e-03, 2.53e-04) | RL2(rho,u,p)=(2.46e-02, 1.88e-01, 2.38e-02)
# [Stage 2] iter=03600, time=47.15s, loss=1.60e-01 | MSE(rho,u,p)=(2.82e-04, 6.92e-03, 2.71e-04) | RL2(rho,u,p)=(2.46e-02, 1.92e-01, 2.47e-02)
# [Stage 2] iter=03700, time=48.42s, loss=1.77e-01 | MSE(rho,u,p)=(2.87e-04, 7.23e-03, 2.83e-04) | RL2(rho,u,p)=(2.48e-02, 1.96e-01, 2.52e-02)
# [Stage 2] iter=03800, time=49.70s, loss=1.50e-01 | MSE(rho,u,p)=(3.11e-04, 6.85e-03, 2.67e-04) | RL2(rho,u,p)=(2.58e-02, 1.91e-01, 2.45e-02)
# [Stage 2] iter=03900, time=50.98s, loss=1.94e-01 | MSE(rho,u,p)=(2.67e-04, 6.69e-03, 2.59e-04) | RL2(rho,u,p)=(2.39e-02, 1.89e-01, 2.41e-02)
# [Stage 2] iter=04000, time=52.25s, loss=2.22e-01 | MSE(rho,u,p)=(2.87e-04, 6.83e-03, 2.65e-04) | RL2(rho,u,p)=(2.48e-02, 1.91e-01, 2.44e-02)
# [Stage 2] iter=04100, time=53.53s, loss=3.07e-01 | MSE(rho,u,p)=(2.70e-04, 6.87e-03, 2.70e-04) | RL2(rho,u,p)=(2.41e-02, 1.91e-01, 2.46e-02)
# [Stage 2] iter=04200, time=54.81s, loss=9.81e-02 | MSE(rho,u,p)=(3.22e-04, 6.90e-03, 2.95e-04) | RL2(rho,u,p)=(2.63e-02, 1.92e-01, 2.57e-02)
# [Stage 2] iter=04300, time=56.08s, loss=2.40e-01 | MSE(rho,u,p)=(2.48e-04, 7.33e-03, 2.71e-04) | RL2(rho,u,p)=(2.31e-02, 1.97e-01, 2.46e-02)
# [Stage 2] iter=04400, time=57.36s, loss=1.26e-01 | MSE(rho,u,p)=(2.68e-04, 6.74e-03, 2.66e-04) | RL2(rho,u,p)=(2.40e-02, 1.89e-01, 2.45e-02)
# [Stage 2] iter=04500, time=58.64s, loss=2.22e-01 | MSE(rho,u,p)=(3.10e-04, 6.15e-03, 3.32e-04) | RL2(rho,u,p)=(2.58e-02, 1.81e-01, 2.73e-02)
# [Stage 2] iter=04600, time=59.91s, loss=1.90e-01 | MSE(rho,u,p)=(2.58e-04, 6.70e-03, 2.94e-04) | RL2(rho,u,p)=(2.36e-02, 1.89e-01, 2.57e-02)
# [Stage 2] iter=04700, time=61.19s, loss=1.46e-01 | MSE(rho,u,p)=(2.67e-04, 6.46e-03, 2.60e-04) | RL2(rho,u,p)=(2.39e-02, 1.85e-01, 2.42e-02)
# [Stage 2] iter=04800, time=62.47s, loss=1.60e-01 | MSE(rho,u,p)=(2.67e-04, 6.51e-03, 2.51e-04) | RL2(rho,u,p)=(2.39e-02, 1.86e-01, 2.37e-02)
# [Stage 2] iter=04900, time=63.75s, loss=4.66e-01 | MSE(rho,u,p)=(2.70e-04, 6.07e-03, 2.55e-04) | RL2(rho,u,p)=(2.41e-02, 1.80e-01, 2.39e-02)
# [Stage 2] iter=05000, time=65.03s, loss=1.14e-01 | MSE(rho,u,p)=(2.27e-04, 5.89e-03, 2.39e-04) | RL2(rho,u,p)=(2.21e-02, 1.77e-01, 2.32e-02)
# [Stage 2] iter=05100, time=66.31s, loss=1.21e-01 | MSE(rho,u,p)=(2.23e-04, 5.07e-03, 2.26e-04) | RL2(rho,u,p)=(2.19e-02, 1.64e-01, 2.25e-02)
# [Stage 2] iter=05200, time=67.59s, loss=1.25e-01 | MSE(rho,u,p)=(1.91e-04, 3.50e-03, 1.68e-04) | RL2(rho,u,p)=(2.02e-02, 1.36e-01, 1.94e-02)
# [Stage 2] iter=05300, time=68.87s, loss=1.79e-01 | MSE(rho,u,p)=(1.67e-04, 2.95e-03, 1.56e-04) | RL2(rho,u,p)=(1.89e-02, 1.25e-01, 1.87e-02)
# [Stage 2] iter=05400, time=70.14s, loss=1.62e-01 | MSE(rho,u,p)=(1.32e-04, 1.97e-03, 1.20e-04) | RL2(rho,u,p)=(1.68e-02, 1.02e-01, 1.64e-02)
# [Stage 2] iter=05500, time=71.42s, loss=5.92e-02 | MSE(rho,u,p)=(1.13e-04, 1.41e-03, 9.97e-05) | RL2(rho,u,p)=(1.56e-02, 8.66e-02, 1.50e-02)
# [Stage 2] iter=05600, time=72.70s, loss=1.27e-01 | MSE(rho,u,p)=(1.21e-04, 1.17e-03, 9.99e-05) | RL2(rho,u,p)=(1.61e-02, 7.89e-02, 1.50e-02)
# [Stage 2] iter=05700, time=73.97s, loss=5.40e-02 | MSE(rho,u,p)=(1.06e-04, 1.14e-03, 9.39e-05) | RL2(rho,u,p)=(1.51e-02, 7.80e-02, 1.45e-02)
# [Stage 2] iter=05800, time=75.25s, loss=1.64e-01 | MSE(rho,u,p)=(1.19e-04, 1.04e-03, 9.93e-05) | RL2(rho,u,p)=(1.60e-02, 7.42e-02, 1.49e-02)
# [Stage 2] iter=05900, time=76.53s, loss=2.90e-01 | MSE(rho,u,p)=(1.31e-04, 1.01e-03, 1.09e-04) | RL2(rho,u,p)=(1.68e-02, 7.33e-02, 1.56e-02)
# [Stage 2] iter=06000, time=77.80s, loss=9.67e-02 | MSE(rho,u,p)=(9.65e-05, 8.01e-04, 7.65e-05) | RL2(rho,u,p)=(1.44e-02, 6.53e-02, 1.31e-02)
# [Stage 2] iter=06100, time=79.08s, loss=1.25e-01 | MSE(rho,u,p)=(1.16e-04, 8.87e-04, 7.99e-05) | RL2(rho,u,p)=(1.58e-02, 6.87e-02, 1.34e-02)
# [Stage 2] iter=07700, time=99.52s, loss=3.94e-02 | MSE(rho,u,p)=(8.24e-05, 7.95e-04, 7.78e-05) | RL2(rho,u,p)=(1.33e-02, 6.50e-02, 1.32e-02)
# [Stage 2] iter=07800, time=100.79s, loss=1.39e-01 | MSE(rho,u,p)=(9.04e-05, 8.40e-04, 8.94e-05) | RL2(rho,u,p)=(1.39e-02, 6.69e-02, 1.42e-02)
# [Stage 2] iter=07900, time=102.07s, loss=6.18e-02 | MSE(rho,u,p)=(8.53e-05, 7.53e-04, 8.04e-05) | RL2(rho,u,p)=(1.35e-02, 6.33e-02, 1.34e-02)
# [Stage 2] iter=08000, time=103.35s, loss=1.60e-01 | MSE(rho,u,p)=(8.49e-05, 9.43e-04, 9.96e-05) | RL2(rho,u,p)=(1.35e-02, 7.08e-02, 1.50e-02)
# [Stage 2] iter=08100, time=104.62s, loss=2.19e-01 | MSE(rho,u,p)=(1.19e-04, 9.05e-04, 1.38e-04) | RL2(rho,u,p)=(1.60e-02, 6.94e-02, 1.76e-02)
# [Stage 2] iter=08200, time=105.90s, loss=1.08e-01 | MSE(rho,u,p)=(9.98e-05, 9.16e-04, 9.03e-05) | RL2(rho,u,p)=(1.46e-02, 6.98e-02, 1.42e-02)
# [Stage 2] iter=08300, time=107.18s, loss=4.47e-02 | MSE(rho,u,p)=(9.69e-05, 1.14e-03, 1.06e-04) | RL2(rho,u,p)=(1.44e-02, 7.79e-02, 1.54e-02)
# [Stage 2] iter=08400, time=108.45s, loss=1.79e-01 | MSE(rho,u,p)=(1.07e-04, 9.65e-04, 1.34e-04) | RL2(rho,u,p)=(1.52e-02, 7.17e-02, 1.73e-02)
# [Stage 2] iter=08500, time=109.73s, loss=1.04e-01 | MSE(rho,u,p)=(9.18e-05, 1.01e-03, 9.38e-05) | RL2(rho,u,p)=(1.40e-02, 7.34e-02, 1.45e-02)
# [Stage 2] iter=08600, time=111.01s, loss=3.13e-02 | MSE(rho,u,p)=(1.07e-04, 9.75e-04, 8.98e-05) | RL2(rho,u,p)=(1.51e-02, 7.20e-02, 1.42e-02)
# [Stage 2] iter=08700, time=112.29s, loss=6.22e-02 | MSE(rho,u,p)=(9.13e-05, 9.75e-04, 8.97e-05) | RL2(rho,u,p)=(1.40e-02, 7.20e-02, 1.42e-02)
# [Stage 2] iter=08800, time=113.56s, loss=3.43e-02 | MSE(rho,u,p)=(1.02e-04, 9.45e-04, 9.68e-05) | RL2(rho,u,p)=(1.48e-02, 7.09e-02, 1.47e-02)
# [Stage 2] iter=08900, time=114.84s, loss=6.76e-02 | MSE(rho,u,p)=(9.25e-05, 1.02e-03, 9.87e-05) | RL2(rho,u,p)=(1.41e-02, 7.38e-02, 1.49e-02)
# [Stage 2] iter=09000, time=116.12s, loss=8.14e-02 | MSE(rho,u,p)=(9.68e-05, 1.09e-03, 9.59e-05) | RL2(rho,u,p)=(1.44e-02, 7.61e-02, 1.47e-02)
# [Stage 2] iter=09100, time=117.40s, loss=7.64e-02 | MSE(rho,u,p)=(8.51e-05, 1.05e-03, 9.77e-05) | RL2(rho,u,p)=(1.35e-02, 7.46e-02, 1.48e-02)
# [Stage 2] iter=09200, time=118.67s, loss=1.03e-01 | MSE(rho,u,p)=(1.19e-04, 9.68e-04, 8.66e-05) | RL2(rho,u,p)=(1.60e-02, 7.17e-02, 1.39e-02)
# [Stage 2] iter=09300, time=119.95s, loss=8.87e-02 | MSE(rho,u,p)=(1.05e-04, 1.18e-03, 1.06e-04) | RL2(rho,u,p)=(1.50e-02, 7.92e-02, 1.55e-02)
# [Stage 2] iter=09400, time=121.23s, loss=8.74e-02 | MSE(rho,u,p)=(9.66e-05, 1.10e-03, 9.81e-05) | RL2(rho,u,p)=(1.44e-02, 7.63e-02, 1.48e-02)
# [Stage 2] iter=09500, time=122.51s, loss=1.10e-01 | MSE(rho,u,p)=(1.01e-04, 9.59e-04, 1.10e-04) | RL2(rho,u,p)=(1.48e-02, 7.14e-02, 1.57e-02)
# [Stage 2] iter=09600, time=123.79s, loss=7.13e-02 | MSE(rho,u,p)=(1.06e-04, 1.14e-03, 1.09e-04) | RL2(rho,u,p)=(1.51e-02, 7.77e-02, 1.56e-02)
# [Stage 2] iter=09700, time=125.06s, loss=3.95e-02 | MSE(rho,u,p)=(1.08e-04, 1.11e-03, 9.97e-05) | RL2(rho,u,p)=(1.52e-02, 7.68e-02, 1.50e-02)
# [Stage 2] iter=09800, time=126.34s, loss=1.65e-01 | MSE(rho,u,p)=(1.08e-04, 1.04e-03, 1.32e-04) | RL2(rho,u,p)=(1.52e-02, 7.43e-02, 1.72e-02)
# [Stage 2] iter=09900, time=127.62s, loss=8.84e-02 | MSE(rho,u,p)=(1.31e-04, 1.17e-03, 1.19e-04) | RL2(rho,u,p)=(1.68e-02, 7.88e-02, 1.64e-02)
# [Stage 2] iter=10000, time=128.90s, loss=5.34e-02 | MSE(rho,u,p)=(9.68e-05, 1.30e-03, 1.05e-04) | RL2(rho,u,p)=(1.44e-02, 8.31e-02, 1.54e-02)
# Plotting test grid: nt=129, nx=257
# Evaluation errors:
#   rho: MSE=9.679107e-05, RL2=1.441965e-02
#   u  : MSE=1.298954e-03, RL2=8.312836e-02
#   p  : MSE=1.050889e-04, RL2=1.535845e-02
# (array([9.67910746e-05, 1.29895413e-03, 1.05088904e-04], dtype=float32),
#  array([0.01441965, 0.08312836, 0.01535845], dtype=float32))

# %%
save_training_results(
        pde_params_by_stage={
            "stage1": pde_params_stage1,
            "stage2": pde_params_stage2,
        },
        coor_params_by_stage={
            "stage1": coor_params_stage1,
        },
        pde_histories_by_stage={
            "stage1": history_stage1,
            "stage2": history_stage2,
        },
        checkpoint_path=save_path,
    )
# Out:
# Training checkpoint saved to: /home/DG21210022/Amon/tal/shocktube/talpinn_sod03.msgpack
# Training histories saved to: /home/DG21210022/Amon/tal/shocktube/talpinn_sod03_history.npz
